# %% [markdown]
# # Data Wrangling - Chicago Business Licenses 2019

# %% [markdown]
# ## Set up the environment

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from mpl_toolkits.axes_grid1 import make_axes_locatable

import seaborn as sns
import math
import googlemaps
import geopandas
from collections import Counter

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\aroge\\Documents\\GitHub\\Springboard\\Chicago_Crime'

# %% [markdown]
# ## Import the Business Licenses file

# %% [markdown]
# The dataset is from the Chicago Data Portal, Business Licenses. Since we are interested in businesses that were active in 2019, the dataset contains all licenses with "license term expiration date" in 2019 and later, and "license term start date" in 2019 and earlier.

# %%
bl = pd.read_csv('business_licenses_2019.csv')
# Out:
# C:\Users\aroge\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# ## Inspect the data

# %%
bl.dtypes
# Out:
# ID                                    object
# LICENSE ID                             int64
# ACCOUNT NUMBER                         int64
# SITE NUMBER                            int64
# LEGAL NAME                            object
# DOING BUSINESS AS NAME                object
# ADDRESS                               object
# CITY                                  object
# STATE                                 object
# ZIP CODE                              object
# WARD                                 float64
# PRECINCT                             float64
# WARD PRECINCT                         object
# POLICE DISTRICT                      float64
# LICENSE CODE                           int64
# LICENSE DESCRIPTION                   object
# BUSINESS ACTIVITY ID                  object
# BUSINESS ACTIVITY                     object
# LICENSE NUMBER                         int64
# APPLICATION TYPE                      object
# APPLICATION CREATED DATE              object
# APPLICATION REQUIREMENTS COMPLETE     object
# PAYMENT DATE                          object
# CONDITIONAL APPROVAL                  object
# LICENSE TERM START DATE               object
# LICENSE TERM EXPIRATION DATE          object
# LICENSE APPROVED FOR ISSUANCE         object
# DATE ISSUED                           object
# LICENSE STATUS                        object
# LICENSE STATUS CHANGE DATE            object
# SSA                                  float64
# LATITUDE                             float64
# LONGITUDE                            float64
# LOCATION                              object
# dtype: object

# %%
bl['APPLICATION CREATED DATE'] = pd.to_datetime(bl['APPLICATION CREATED DATE'])  
bl['APPLICATION REQUIREMENTS COMPLETE'] = pd.to_datetime(bl['APPLICATION REQUIREMENTS COMPLETE'])  
bl['PAYMENT DATE'] = pd.to_datetime(bl['PAYMENT DATE'])  
bl['LICENSE TERM START DATE'] = pd.to_datetime(bl['LICENSE TERM START DATE'])  
bl['LICENSE TERM EXPIRATION DATE'] = pd.to_datetime(bl['LICENSE TERM EXPIRATION DATE'])  
bl['LICENSE APPROVED FOR ISSUANCE'] = pd.to_datetime(bl['LICENSE APPROVED FOR ISSUANCE'])  
bl['DATE ISSUED'] = pd.to_datetime(bl['DATE ISSUED'])  
bl['LICENSE STATUS CHANGE DATE'] = pd.to_datetime(bl['LICENSE STATUS CHANGE DATE'])  
#bl['LICENSE STATUS CHANGE DATE'] = bl['LICENSE STATUS CHANGE DATE'].dt.normalize()
bl.dtypes
# Out:
# ID                                           object
# LICENSE ID                                    int64
# ACCOUNT NUMBER                                int64
# SITE NUMBER                                   int64
# LEGAL NAME                                   object
# DOING BUSINESS AS NAME                       object
# ADDRESS                                      object
# CITY                                         object
# STATE                                        object
# ZIP CODE                                     object
# WARD                                        float64
# PRECINCT                                    float64
# WARD PRECINCT                                object
# POLICE DISTRICT                             float64
# LICENSE CODE                                  int64
# LICENSE DESCRIPTION                          object
# BUSINESS ACTIVITY ID                         object
# BUSINESS ACTIVITY                            object
# LICENSE NUMBER                                int64
# APPLICATION TYPE                             object
# APPLICATION CREATED DATE             datetime64[ns]
# APPLICATION REQUIREMENTS COMPLETE    datetime64[ns]
# PAYMENT DATE                         datetime64[ns]
# CONDITIONAL APPROVAL                         object
# LICENSE TERM START DATE              datetime64[ns]
# LICENSE TERM EXPIRATION DATE         datetime64[ns]
# LICENSE APPROVED FOR ISSUANCE        datetime64[ns]
# DATE ISSUED                          datetime64[ns]
# LICENSE STATUS                               object
# LICENSE STATUS CHANGE DATE           datetime64[ns]
# SSA                                         float64
# LATITUDE                                    float64
# LONGITUDE                                   float64
# LOCATION                                     object
# dtype: object

# %%
bl.shape
# Out:
# (99029, 34)

# %%
bl.head()
# Out:
#                  ID  LICENSE ID  ACCOUNT NUMBER  SITE NUMBER  \
# 0  2609257-20180711     2609257          428254            2
# 1  2608406-20180621     2608406          356957            4
# 2  2636934-20181205     2636934           44897            7
# 3  2641788-20190102     2641788          396358            3
# 4  2608534-20180705     2608534          310581           11
#
#                    LEGAL NAME               DOING BUSINESS AS NAME  \
# 0            ART OF DOSA, LLC                          ART OF DOSA
# 1    HAROLD'S ON WABASH, INC.                     HAROLD'S CHICKEN
# 2               ERIC WILLIAMS                      THE SILVER ROOM
# 3        WINDY CITY PLAYHOUSE                 WINDY CITY PLAYHOUSE
# 4  GARIFUNA ENTERPRISES, INC.  GARIFUNA FLAVA CARIBBEAN RESTAURANT
#
#                     ADDRESS     CITY STATE ZIP CODE  ...  \
# 0          820 N ORLEANS ST  CHICAGO    IL    60610  ...
# 1          2300 S THROOP ST  CHICAGO    IL    60608  ...
# 2      1302 N MILWAUKEE AVE  CHICAGO    IL    60622  ...
# 3  2229 S MICHIGAN AVE  101  CHICAGO    IL    60616  ...
# 4            2518 W 63RD ST  CHICAGO    IL    60629  ...
#
#    LICENSE TERM START DATE  LICENSE TERM EXPIRATION DATE  \
# 0               2018-07-11                    2019-01-02
# 1               2018-06-21                    2019-01-04
# 2               2018-12-05                    2019-01-05
# 3               2019-01-02                    2019-01-06
# 4               2018-07-05                    2019-01-07
#
#   LICENSE APPROVED FOR ISSUANCE  DATE ISSUED  LICENSE STATUS  \
# 0                    2018-07-11   2018-07-11             AAI
# 1                    2018-06-21   2018-06-21             AAI
# 2                    2018-12-05   2018-12-05             AAI
# 3                    2019-01-02   2019-01-02             AAI
# 4                    2018-07-05   2018-07-05             AAI
#
#   LICENSE STATUS CHANGE DATE   SSA   LATITUDE  LONGITUDE  \
# 0                        NaT   NaN  41.897338 -87.637345
# 1                        NaT   NaN  41.850451 -87.658798
# 2                        NaT  33.0  41.905243 -87.669647
# 3                        NaT   NaN  41.852019 -87.623635
# 4                        NaT   3.0  41.779320 -87.686974
#
#                                    LOCATION
# 0  (41.897338047455214, -87.63734543001038)
# 1      (41.85045102427, -87.65879785567869)
# 2  (41.905243179899976, -87.66964736332534)
# 3   (41.85201901299171, -87.62363504682149)
# 4   (41.779320429504864, -87.6869743899248)
#
# [5 rows x 34 columns]

# %%
bl['CITY'].value_counts()
# Out:
# CHICAGO                    90324
# NORTHBROOK                   139
# SKOKIE                       127
# DES PLAINES                  122
# NAPERVILLE                   121
#                            ...
# QUEZON CITY PHILIPPINES        1
# VALLEY VIEW                    1
# EAST LANSING                   1
# BRANFORD                       1
# HAMILTON                       1
# Name: CITY, Length: 1174, dtype: int64

# %%
bl.isnull().sum()
# Out:
# ID                                       0
# LICENSE ID                               0
# ACCOUNT NUMBER                           0
# SITE NUMBER                              0
# LEGAL NAME                               0
# DOING BUSINESS AS NAME                  55
# ADDRESS                                  0
# CITY                                     2
# STATE                                    0
# ZIP CODE                               113
# WARD                                  8746
# PRECINCT                             19590
# WARD PRECINCT                         8730
# POLICE DISTRICT                      19012
# LICENSE CODE                             0
# LICENSE DESCRIPTION                      0
# BUSINESS ACTIVITY ID                 11416
# BUSINESS ACTIVITY                    11416
# LICENSE NUMBER                           0
# APPLICATION TYPE                         0
# APPLICATION CREATED DATE             75816
# APPLICATION REQUIREMENTS COMPLETE      342
# PAYMENT DATE                           650
# CONDITIONAL APPROVAL                     0
# LICENSE TERM START DATE                  0
# LICENSE TERM EXPIRATION DATE             0
# LICENSE APPROVED FOR ISSUANCE         3203
# DATE ISSUED                              0
# LICENSE STATUS                           0
# LICENSE STATUS CHANGE DATE           94381
# SSA                                  74316
# LATITUDE                             10291
# LONGITUDE                            10291
# LOCATION                             10291
# dtype: int64

# %%
print("The Business Licenses file has", bl.shape[0], "rows, of which",
      bl[bl.LATITUDE.isnull()].shape[0], "rows have NULL location data.")
# Out:
# The Business Licenses file has 99029 rows, of which 10291 rows have NULL location data.

# %% [markdown]
# ## Exploration of rows with NULL location data

# %%
bl_nulls = bl[bl.LATITUDE.isnull()]
print(bl_nulls['CITY'].value_counts())
# Out:
# CHICAGO              1967
# NORTHBROOK            138
# SKOKIE                126
# NAPERVILLE            120
# DES PLAINES           102
#                      ...
# ST CLAIR SHORES         1
# GROSSE POINTE           1
# ONEIDA                  1
# TUCKER                  1
# NORTH KANSAS CITY       1
# Name: CITY, Length: 1142, dtype: int64

# %% [markdown]
# We see that while "Chicago" is the most common city, around 80% of the other rows are for businesses with addresses outside Chicago. (They are licensed to conduct business in Chicago.)

# %%
print(bl_nulls[bl_nulls['CITY'] == 'CHICAGO']['ADDRESS'].value_counts())
# Out:
# [REDACTED FOR PRIVACY]             1009
# 950 W ADDISON ST LL, 1 & 4           10
# 151 E WACKER DR  PLAZA                9
# 101 E ERIE ST 1, 8-21                 9
# 10 S CLINTON ST 1,2,3                 9
#                                    ...
# 2214 E 7OTH PL 1ST 107                1
# 111 W WACKER DR 4-12,14               1
# 2100 N DAMEN AVE STREET LEVEL         1
# 6969 N RAVENSWOOD AVE 1ST A,B,C       1
# 56 E WALTON ST 1, 2 AND 3             1
# Name: ADDRESS, Length: 493, dtype: int64

# %% [markdown]
# Of the businesses located in Chicago with NULL location data, over half have had their street address redacted by the Chicago Data Portal.

# %% [markdown]
# ### Redacted Addresses

# %%
# For those with Redacted Addresses, find the types of businesses

bl_redacted_addresses = bl_nulls.query(
    'CITY == "CHICAGO" and ADDRESS == "[REDACTED FOR PRIVACY]"')

print("License Descriptions")
print(bl_redacted_addresses['LICENSE DESCRIPTION'].value_counts())
# Out:
# License Descriptions
# Pharmaceutical Representative    632
# Regulated Business License       377
# Name: LICENSE DESCRIPTION, dtype: int64

# %%
print("Business Activities")
print(bl_redacted_addresses['BUSINESS ACTIVITY'].value_counts())
# Out:
# Business Activities
# Markets / Promotes Pharmaceuticals to Health Care Professionals and Conducts Business for More than 15 Calendar Days per Year                                                         632
# Vacation Rental - Approved Prior to House Share Ordinance                                                                                                                             168
# Vacation Rental Building Containing Five or More Dwelling Units For Transient Occupancy                                                                                               124
# Bed and Breakfast Establishment, Owner-Occupied, 11 or Fewer Sleeping Rooms Available for Rent for Transient Occupancy by Registered Guests                                            35
# Vacation Rental Building Containing Two to Four Dwelling Units For Transient Occupancy                                                                                                 33
# Vacation Rental - Commissioner's Adjustment | Vacation Rental Building Containing Two to Four Dwelling Units For Transient Occupancy                                                    5
# Vacation Rental Building of a Dwelling Unit That is a Single Family Home                                                                                                                4
# Vacation Rental - Commissioner's Adjustment                                                                                                                                             3
# Vacation Rental - Commissioner's Adjustment | Vacation Rental - Approved Prior to House Share Ordinance                                                                                 3
# Vacation Rental | Vacation Rental - Commissioner's Adjustment | Vacation Rental - Approved Prior to House Share Ordinance                                                               1
# Vacation Rental Building of a Dwelling Unit That is a Single Family Home | Vacation Rental - Commissioner's Adjustment | Vacation Rental - Approved Prior to House Share Ordinance      1
# Name: BUSINESS ACTIVITY, dtype: int64

# %% [markdown]
# The businesses with redacted address information are pharmaceutical reps and various kinds of vacation rentals (including bed and breakfast establishments).

# %% [markdown]
# ### Other businesses in Chicago without redacted address data

# %%
bl_missing_loc = bl_nulls.query(
    'CITY == "CHICAGO" and ADDRESS != "[REDACTED FOR PRIVACY]"')

print("There are", bl_missing_loc.shape[0],
      "rows of data for businesses in Chicago with no location data and without redacted address data.")
# Out:
# There are 958 rows of data for businesses in Chicago with no location data and without redacted address data.

# %% [markdown]
# This represents about 1% of all business licenses in the dataset.

# %% [markdown]
# ## Removing irrelevant data

# %% [markdown]
# ### Null location data

# %% [markdown]
# As shown in the previous section, location data is missing when businesses located outside Chicago and when the dataset owner redacted the data for privacy of the license holders.
#
# About 1% of the data shows businesses with address data in Chicago but no latitude and longitude. It may be worthwhile in the future to lookup the latitude and longitude data for the businesses rows. For now, since this is a small fraction of all data, rows with NULL location data will be dropped from the dataset.

# %%
# Print the number of rows in the original dataframe
print("Number of rows in original dataframe =", bl.shape[0])

# Create a new dataframe without the rows with NULL location data
null_locations = bl[bl.LATITUDE.isnull()].index
bl_trimmed = bl.drop(null_locations)

# Print the number of rows in the new dataframe
print("Number of rows in cleaned dataframe =", bl_trimmed.shape[0])
# Out:
# Number of rows in original dataframe = 99029
# Number of rows in cleaned dataframe = 88738

# %% [markdown]
# ### Canceled and revoked licenses

# %% [markdown]
# Delete the rows for licenses canceled or revoked before 2019.

# %%
# Find all rows for licenses canceled or revoked before 2019
canceled = ((bl_trimmed['LICENSE STATUS'] == "AAC") |
            (bl_trimmed['LICENSE STATUS'] == "REV")) & (
                bl_trimmed['LICENSE STATUS CHANGE DATE'] < '2019-01-01')

# Print the counts of total rows and rows to be dropped
print('Rows before dropping:', bl_trimmed.shape[0])
print('Licenses canceled or revoked before 2019:',
      bl_trimmed[canceled].shape[0])

# Using the inverted boolean, select just the rows that don't meet the condition

bl_trimmed = bl_trimmed[~canceled]
print('Rows after dropping:', bl_trimmed.shape[0])
# Out:
# Rows before dropping: 88738
# Licenses canceled or revoked before 2019: 1805
# Rows after dropping: 86933

# %% [markdown]
# ### "INQ" licenses

# %% [markdown]
# Delete the rows for licenses status = Inquiry.

# %%
# Find all license inquiries
inquiries = bl_trimmed['LICENSE STATUS'] == "INQ"

# Print the counts of total rows and rows to be dropped
print('Rows before dropping:', bl_trimmed.shape[0])
print('License inquiries:',
      bl_trimmed[inquiries].shape[0])

# Using the inverted boolean, keep just the rows that don't meet the condition

bl_trimmed = bl_trimmed[~inquiries]
print('Rows after dropping:', bl_trimmed.shape[0])
# Out:
# Rows before dropping: 86933
# License inquiries: 2
# Rows after dropping: 86931

# %% [markdown]
# ### Canceled before term started

# %%
# Find all rows for licenses canceled or revoked before 2019
canceled = (bl_trimmed['LICENSE STATUS CHANGE DATE'] <= bl_trimmed['LICENSE TERM START DATE'])

# Print the counts of total rows and rows to be dropped
print('Rows before dropping:', bl_trimmed.shape[0])
print('Licenses canceled or revoked before 2019:',
      bl_trimmed[canceled].shape[0])

# Using the inverted boolean, select just the rows that don't meet the condition

bl_trimmed = bl_trimmed[~canceled]
print('Rows after dropping:', bl_trimmed.shape[0])
# Out:
# Rows before dropping: 86931
# Licenses canceled or revoked before 2019: 24
# Rows after dropping: 86907

# %% [markdown]
# ### Expired before term started

# %%
# Find all rows for licenses canceled or revoked before 2019
canceled = (bl_trimmed['LICENSE TERM EXPIRATION DATE'] < bl_trimmed['LICENSE TERM START DATE'])

# Print the counts of total rows and rows to be dropped
print('Rows before dropping:', bl_trimmed.shape[0])
print('Licenses canceled or revoked before 2019:',
      bl_trimmed[canceled].shape[0])

# Using the inverted boolean, select just the rows that don't meet the condition

bl_trimmed = bl_trimmed[~canceled]
print('Rows after dropping:', bl_trimmed.shape[0])
# Out:
# Rows before dropping: 86907
# Licenses canceled or revoked before 2019: 29
# Rows after dropping: 86878

# %% [markdown]
# ## Duplicate rows

# %% [markdown]
# When a license expired and was renewed in 2019, there will be 2 rows in the data. Remove instances where multiple rows share same Location and License Code. This assumes that there is only one business of a given type at a location.

# %%
bl_trimmed = bl_trimmed.drop_duplicates(subset=['LICENSE CODE', 'LOCATION'])
print('Rows after dropping:', bl_trimmed.shape[0])
# Out:
# Rows after dropping: 50401

# %% [markdown]
# ## License codes and descriptions

# %% [markdown]
# ### Create a dictionary of License Codes

# %%
# Create a new dataframe of just 2 columns. 
bl_lic_cd = bl_trimmed.filter(['LICENSE CODE', 'LICENSE DESCRIPTION'])

#To speed processing, Drop duplicates.
bl_lic_cd = bl_lic_cd.drop_duplicates(subset=['LICENSE CODE', 'LICENSE DESCRIPTION'])

# Drop null values
bl_lic_cd = bl_lic_cd.dropna()

print(bl_lic_cd.sort_values(by=['LICENSE DESCRIPTION'])['LICENSE DESCRIPTION'])
# Out:
# 34928                                          Affiliation
# 489                                    Animal Care License
# 25114                            Bicycle Messenger Service
# 199                               Caterer's Liquor License
# 12                    Children's Services Facility License
# 1629                                     Commercial Garage
# 45962                          Commercial Passenger Vessel
# 185          Consumption on Premises - Incidental Activity
# 34971                                    Emerging Business
# 10765                                           Explosives
# 210                                        Filling Station
# 12217                                Food - Shared Kitchen
# 1970                  Food - Shared Kitchen - Supplemental
# 2669                                             Heliports
# 3                                     Indoor Special Event
# 1335                                             Late Hour
# 31572                                      License Manager
# 7                                 Limited Business License
# 221                           Manufacturing Establishments
# 27660                                Massage Establishment
# 862                                    Mobile Food License
# 105                         Motor Vehicle Services License
# 2747                                       Music and Dance
# 6157                               Navy Pier Kiosk License
# 472                                    Not-For-Profit Club
# 300                                          Outdoor Patio
# 90                                           Package Goods
# 1090                                            Pawnbroker
# 79                                         Peddler License
# 40735                  Pop-Up Establishment Host - Tier II
# 59200                       Pop-Up Food Est. User - Tier I
# 6610                       Pop-Up Food Est. User - Tier II
# 20025                     Pop-Up Food Est. User - Tier III
# 2                                       Pop-Up Retail User
# 15078                         Private Booting Registration
# 10                               Public Place of Amusement
# 86                                                 Raffles
# 34                              Regulated Business License
# 12854    Retail Food - Seasonal Lakefront Food Establis...
# 52                               Retail Food Establishment
# 277                                      Secondhand Dealer
# 7035                          Shared Housing Unit Operator
# 308                                    Shared Kitchen User
# 0                                       Special Event Food
# 5229                                  Special Event Liquor
# 88                                                  Tavern
# 34936             Taxicab Two-Way Dispatch Service License
# 63                                                 Tobacco
# 8664                       Transportation Network Provider
# 531                                 Valet Parking Operator
# 276                           Wholesale Food Establishment
# 31621                                        Wrigley Field
# Name: LICENSE DESCRIPTION, dtype: object

# %% [markdown]
# ## Business Activity columns

# %% [markdown]
# ### Create a dictionary of Business Activities

# %%
# Create a new dataframe of just 2 columns. 
bl_bus_acts = bl_trimmed.filter(['BUSINESS ACTIVITY ID', 'BUSINESS ACTIVITY'])

#To speed processing, Drop duplicates.
bl_bus_acts = bl_bus_acts.drop_duplicates(subset=['BUSINESS ACTIVITY ID', 'BUSINESS ACTIVITY'])

# Drop null values
bl_bus_acts = bl_bus_acts.dropna()

print(bl_bus_acts)
# Out:
#       BUSINESS ACTIVITY ID                                  BUSINESS ACTIVITY
# 0                      946              180 Day Multiple - Special Event Food
# 1                      947  180 Day Multiple - Special Event Food, Mobile ...
# 2                      783        Sale of General Merchandise, Seasonal Items
# 3                      892                               Indoor Special Event
# 7                      922        Retail Sales of Cell Phones and Accessories
# ...                    ...                                                ...
# 97732      708 | 911 | 668  Miscellaneous Commercial Services | Retail Sal...
# 97827            705 | 713  Provide Oil Change and Tire Repair Services | ...
# 98243      904 | 829 | 767  Retail Sales of General Merchandise | Tavern -...
# 98864            660 | 722  Financial Services (Home Based Business) | Onl...
# 98933      648 | 911 | 631  Dry Cleaning - Drop Off Location | Retail Sale...
#
# [2482 rows x 2 columns]

# %%
bl_bus_acts.astype(str)
bl_bus_acts.dtypes
print(bl_bus_acts.iloc[20:25])
# Out:
#    BUSINESS ACTIVITY ID                                  BUSINESS ACTIVITY
# 45            667 | 863  Graphic Design (Home Based Business) | Event P...
# 51                  911     Retail Sales of Clothing / Accessories / Shoes
# 52            904 | 640  Retail Sales of General Merchandise | Deli, Bu...
# 53                  730  Photographer, Portrait Artist, Videographer (H...
# 54                  674         Home Repair Services (Home Based Business)

# %%
# Populate a dictionary with the Business Activities

ba_dict = {}

for i in bl_bus_acts.index:

    # Parse the fields, which are delimited by " | "
    ba_list = bl_bus_acts['BUSINESS ACTIVITY'][i].split(' | ')
    ba_id_list = bl_bus_acts['BUSINESS ACTIVITY ID'][i].split(' | ')
    for single_ba_id in ba_id_list:
        ba_dict[single_ba_id] = ba_list[ba_id_list.index(single_ba_id)]

# %%
# Print the Business Activity dictionary
print("There are", len(ba_dict), "distinct business activity values:")
for key in sorted(ba_dict):
    print(key, ba_dict[key])
# Out:
# There are 343 distinct business activity values:
# 1000 Provide Chair Massage - Fully Clothed/No Disrobing
# 1001 Taxi Affiliation and Two Way Radio Dispatch
# 1011 Operation of a Commercial Passenger Vessel - Under 20 Passengers
# 1012 Operation of a Commercial Passenger Vessel - 20 or More Passengers
# 1018 1 Year Pop-Up Food Est. User - Tier I (Sale of Pre-Packaged, Non-Perishable Food)
# 1021 90 Day Pop-Up Food Est. User - Tier II (Sale of Pre-Packaged, Prepared Hot/Cold Food, Final Prep On-Site)
# 1024 90 Day Pop-Up Food Est. User - Tier III (Prepare and Serve Hot/Cold Food On-Site)
# 1025 Pop-Up Food Est. User Host - Tier II (Pre-Packaged Prepared Hot/Cold Food. Final Prep On-Site)
# 1027 Organizer of a 1-5 Day Event w/ Pop-Up Retail Users at a Trade Show, Exhibition or Convention
# 1028 Organizer of a 6-30 Day Event w/ Pop- Up Retail Users at a Trade Show, Exhibition or Convention
# 1029 Organizer of a 31-90 Day Event w/ Pop-Up Retail Users at a Trade Show, Exhibition or Convention
# 1030 Organizer of a 91-180 Day Event w/ Pop-Up Retail Users at a Trade Show, Exhibition or Convention
# 1031 Organizer of a 181-365 Day Event w/ Pop-Up Retail Users at a Trade Show, Exhibition or Convention
# 1032 1-5 Day Pop-Up Retail User, Sale of General Merchandise/Seasonal Items
# 1033 6-30 Day Pop-Up Retail User, Sale of General Merchandise/Seasonal Items
# 1034 1-90 Day Pop-Up Retail User, Sale of General Merchandise/Seasonal Items
# 1035 91-180 Day Pop-Up Retail User, Sale of General Merchandise/Seasonal Items
# 1036 181-365 Day Pop-Up Retail User, Sale of General Merchandise/Seasonal Items
# 1038 Operation of a Dockless Scooter Program (Pilot)
# 143 Engage in Body Piercing
# 144 Hair, Nail, and Skin Care Services
# 197 Tax Preparation Services
# 228 Medical Laboratories
# 229 Diagnostic Imaging Centers
# 232 General Medical and Surgical Hospitals
# 236 Assisted Living Establishment
# 362 Sign Manufacturing
# 464 Provide Home Health Care Services
# 476 Photography Services
# 599 Accounting / Tax Preparation (Home Based Business)
# 600 Accounting Services (Tax Preparation, Bookkeeping)
# 601 Acquisition and Improvement of Land/Residential Buildings
# 602 Administrative Commercial Office
# 603 Adult Family Care Center (9 to 11 Adults, 55 Years and Older)
# 606 Taxi Affiliation
# 608 Provide Animal Boarding Services
# 609 Animal Care Facility
# 610 Animal Exhibition (30 Days or More)
# 611 Provide Animal Grooming Services
# 612 Provide Animal Training Services
# 613 Artist Work / Live Space
# 614 Beauty Salon, Hair Salon, Nail Salon
# 616 Bicycle Messenger Service
# 617 Board Up Services for Commercial Locations
# 618 Board Up Services for Residential Locations
# 619 Business and Management Consulting
# 620 Business Consulting
# 621 Buying and Reselling of Used Children's Products
# 622 Buying and Reselling of Used Goods - Non Valuable
# 623 Buying and Reselling of Used Goods - Valuable Objects
# 624 Buying and Reselling of Used Valuable Objects
# 625 Cable or Satellite Installation - Commercial Properties
# 626 Cable or Satellite Installation - Residential Properties
# 627 Operation of an Automatic Car Wash
# 628 Carpet Cleaning Services
# 629 Catering of Liquor From a Business Not Located In Chicago
# 630 Catering of Liquor To Events
# 631 Clothing Alterations
# 632 Commercial Construction
# 633 Commercial Janitorial Services
# 634 Commercial Landscaping Services
# 635 Commissioned Staffing of Professional, Secretarial and Clerical Work
# 636 Computer and Electronic Products Manufacturing
# 637 Computer Consulting Services / Computer Automated Design (Home Based Business)
# 638 Consumption of Liquor on Premises
# 639 Consumption of Liquor on Premises, Not for Profit
# 640 Deli, Butcher or Bakery
# 641 Demolition / Wrecking
# 642 Direct Food Sales to Businesses
# 643 Disc Jockey / Magician / Musician / Enertainer (Home Based Business)
# 645 Distribution, Placing, Leasing or Sales of Automatic Amusement Devices
# 646 Dog Walking, Pet Sitting Services (Home Based Business)
# 647 Drug, Chemical, Paint Factory
# 648 Dry Cleaning - Drop Off Location
# 649 Dry Cleaning - Plant On Premises
# 651 Electrical Equipment, Appliances and Components
# 652 Electronic Equipment Repair
# 653 Employee of a Wrecking/Demolitio/Fireworks Contractor (Cert. of Fitness)
# 654 Employee of Expediter Service
# 655 Engine Repairs and/or Service/Installation of Transmissions
# 656 Equipment Rental For Parties and Events (Home Based Business)
# 657 Exterminator / Pest Control Services
# 658 Fence Installation, Brick Patios, Retaining Walls, Cement Work In Residential Properties
# 659 Financial and Accounting Services
# 660 Financial Services (Home Based Business)
# 661 Fitness Training On and Off Premise
# 662 Flooring and Window Install, Repair or Replace (Home Based Business)
# 663 Food Manufacturing
# 664 Fortune Telling, Astrology, Tarot Card Reading Only
# 665 Freelance Writer (Home Based Business)
# 666 Operation of a Fuel Filling Station
# 667 Graphic Design (Home Based Business)
# 668 Graphic Design and Consultation
# 669 Provide Guard Dog Services
# 670 Health Club
# 671 Operation of a Heliport, Helistop or Vertiport
# 672 Home Health Care Agencies (Home Based Business)
# 673 Home Repair Services
# 674 Home Repair Services (Home Based Business)
# 675 Home, Office, Military, Government Supplies
# 676 Hotel - 7 or More Sleeping Rooms
# 677 Repair of Appliances or Household Goods
# 678 Operate a Not For Profit Humane Society
# 679 Immigration Services
# 680 Immigration Services (Home Based Business)
# 681 Instruction in Art for Both Children and Adults (40% or More Children)
# 682 Instruction in Art for Both Children and Adults (Less Than 40% Children)
# 683 Instruction in Art for Children Under 18 Years of Age
# 684 Instruction in Music for Both Children and Adults (40% or More Children)
# 685 Instruction in Music for Both Children and Adults (Less Than 40% Children)
# 686 Instruction in Music for Children Under 18 Years of Age
# 687 Interior Design / Consulting Services (Home Based Business)
# 688 Jewelry, Watches and Accessories
# 689 Junk Peddler
# 690 Landscaping Services (Home Based Business)
# 691 Language Interpreter, Translator (Home Based Business)
# 692 Laundromat - Self Service
# 693 Laundry Service
# 694 Laundry Service - Drop Off Only
# 696 Taxicab License Manager
# 697 Live Theatrical and Other Live Cultural Performances
# 698 Live Theatrical and Other Live Cultural Performances Where Organization is Operating as an Incidental Use In a Building Primarily Used In The Conduct of Activities of a Not-For-Profit Organization
# 699 Long Term Care Facility
# 700 Machine Shop, Foundry, Roof / Paving Materials
# 701 Machinery Manufacturing
# 702 Marketing / Advertising / Public Relations (Home Based Business)
# 703 Advertising / Marketing / Sales Office
# 705 Provide Oil Change and Tire Repair Services
# 706 Medical Billing (Home Based Business)
# 707 Medical Equipment and Supplies
# 708 Miscellaneous Commercial Services
# 709 Miscellaneous Personal Services
# 711 Motor Vehicle Repair - Engine and Body Work
# 712 Motor Vehicle Repair -  Engine and Transmission Work
# 713 Motor Vehicle Repair - No Engine Work/No Body Work
# 714 Motorized and Non-Motorized Vehicle Parts and Supplies
# 715 Moving Service (Home Based Business)
# 716 Musical Instruments, Games, Toys
# 717 Special Event Beer & Wine
# 718 Non-Human Food / Pet Food
# 719 Professional Consulting (Home Based Business)
# 720 Not-For-Profit Selling Raffles for Prizes of $50 or More
# 721 Off Site Equipment Repair (Computer,TV,  Etc) (Home Occ)
# 722 Online Sales (Home Based Business)
# 723 Organizer of Vendors That Sell for Retail at a Trade Show, Exhibition or Convention
# 724 Other Home Based Businesses
# 725 Provide Parking Spaces For a Fee - Available and Advertised to the Public
# 726 Provide Parking Spaces For a Fee - to Residents, Tenants, Users, Employees and/or Guests (Not Available or Advertised to the Public)
# 727 Payment Center
# 728 Operate a Pet Shop / Sales of Animals
# 729  Pharmacy / Photo Services
# 730 Photographer, Portrait Artist, Videographer (Home Based Business)
# 731 Plastics, Foams, Construction Materials, Glass, Rubber
# 732 Pledging of Property for Money (Pawn)
# 733 Power-Washing Service (Home Based Business)
# 734 Preparation and Sale of Food (ONLY) from a Mobile Food Truck (Mobile Food Preparer)
# 735 Preparation of Food and Dining on Premise With Seating
# 736 Preparation of Food, Coffee or Drinks
# 737 Preparation of License, Certificate or Permit Applications for Compensation
# 738 Preparation of License, Certificate or Permit Applications For Compensation / Expediter (Home Based Business)
# 739 Printing Activities, Metal Processing
# 740 Private Booting of Vehicles
# 741 Private Scavenger - Vehicle
# 742 Provide Amusement Devices for Children - Less Than 3 Devices
# 743 Provides Onsite Amusement or Entertainment
# 744 Provides Onsite Entertainment or Rentals
# 745 Provide Full Body Massage Services
# 746 Public Place of Amusement, Provides Entertainment, Room Rentals and Charges a Fee
# 747 Publishing Services
# 748 Rental of General Merchandise
# 749 Rental of Location for Children's Birthday Parties
# 750 Rental of Musical Instruments
# 751 Renting Computer Terminals for Internet Use
# 752 Residential Cleaning (Home Based Business)
# 753 Residential Cleaning Services
# 754 Residential Construction
# 755 Residential Installations
# 756 Residential Landscaping Services
# 757 Residential Real Estate Developer (Home Based Business)
# 758 Residential Remodeling and Repair (Home Based Business)
# 759 Retail Food-Seasonal Lakefront
# 760 Retail Sale of Food for Offsite Consumption
# 763 Retail Sale of Tobacco
# 764 Retail Sales of Carpet and/or Furniture
# 765 Retail Sales of Food From a Kiosk/Cart/Arcade at Navy Pier
# 766 Retail Sales of Fresh Fruits and Vegetables
# 767 Retail Sales of General Merchandise and Non-Perishable Food
# 768 Retail Sales of General Merchandise and Non-Perishable Food From a Kiosk/Cart/Arcade at Navy Pier
# 769 Peddler- Retail Sales of General Merchandise, Whole Uncut Fruits/Vegetables, Flowers, Moving Along the Public Way
# 770 Peddler - Retail Sales of General Merchandise, Whole Uncut Fruits/Vegetables, Flowers, Moving Along the Public Way (Special)
# 771 Retail Sales of Laundry Cleaning Products
# 772 Retail Sales of New Electronics and Accessories
# 773 Retail Sales of Outdoor Equipment and Supplies
# 774 Retail Sales of Packaged Liquor
# 775 Retail Sales of Perishable Foods
# 776 Retail Sales of Tobacco Products
# 777 Retail Sales of Used Electronics
# 778 Sale and Storage of Tires (1,001 - 5,000)
# 779 Sale and Storage of Tires (100 - 1000)
# 780 Sale and Storage of Tires (5,001 - 10,000)
# 781 Sale of Food Prepared Onsite With Dining Area
# 782 Sale of Food Prepared Onsite Without Dining Area
# 783 Sale of General Merchandise, Seasonal Items
# 784 Sale of Liquor Outdoors on Private Property
# 785 Sale of Liquor Until 4am, Monday - Saturday and 5am on Sunday
# 786 Sales of Previously Prepared Food (ONLY) that is Enclosed or Wrapped In Individual Portions From a Mobile Food Vehicle (Mobile Food Dispenser)
# 792 Sale of Vehicle Parts and Accessories
# 793 Sales / Rental / Lease of Motorized Vehicles
# 796 Sales of Packaged Frozen Desserts From a Non-Motorized Cart (Mobile Desserts Vendor)
# 797 Sales of Produce, Vegetables, Flowers or Beverages From a Non-Motorized Temporary Structure (Produce Merchant)
# 798 Sales of Tickets (Airline, Etc)
# 799 Sales Through an Auction
# 800 Security Services
# 801 Selling Cable, Satellite, or Internet Services
# 802 Shared Kitchen - Operator
# 803 Shared Kitchen - Supplemental
# 804 Shared Kitchen User - Long Term
# 805 Shared Kitchen User - Short Term (90 Days or Less)
# 806 Shipping / Printing Services
# 807 Shoe / Leather Goods Repair
# 809 Operation of Single Room Occupancy Building
# 810 Smoking of Tobacco on Premises
# 811 Smoking of Tobacco With a Mouthpiece Attached to a Container of Water Through Which Smoke is Drawn and Cooled
# 812 Snow Removal Service (Home Based Business)
# 813 Snowplowing
# 816 Storage or Use of Hazardous Materials
# 817 Storage or Use of Hazardous Materials (MFG)
# 818 Storage or Use of Hazardous Materials On Site (MVR)
# 819 Street Performer, Moving Along the Public Way
# 820 Supervision of, and Care for, Children 0-6 Years of Age, During the Day between 6am-9pm
# 821 Supervision of, and Care for, Children 0-6 Years of Age, During the Day between 6am-9pm With Before and After School Programs
# 822 Supervision of, and Care for Children, During the Evening between 9pm-6am
# 823 Supervision of, and Care for, Children 2-6 Years of Age, During the Day between 6am-9pm
# 824 Supervision of, and Care for, Children 2-6 Years of Age, During the Day between 6am-9pm With Before and After School Programs
# 825 Supervision of, and Care for, Children Under 2 Years of Age, During the Day between 6am-9pm
# 826 Supervision of, and Care for, Children Under 2 Years of Age, During the Day between 6am-9pm With Before and After School Programs
# 827 Tanning Facility
# 828 Tattoo / Permanent Body Art and Make-Up / Micro Blading
# 829 Tavern - Consumption of Liquor on Premise
# 830 Taxicab Two-Way Dispatch Service License
# 831 Telephone Answering Service (Home Based Business)
# 833 Temporary Staffing of Workers Where Wage Payments are Made Directly or Indirectly by the Day Labor Agency
# 834 Textile Mills, Apparel, Accessories, Luggage, Wood Products, Leather, Paper Products, Rubber, Petroleum, Coal
# 838 Ticket Sales for Athletic Events or Other Amusement or Any Passenger Ticket
# 839 Provide Towing Services
# 840 Toy, Furniture, Household Goods Factory
# 841 Training in Gymnastics for Both Children and Adults (40% or More Children)
# 843 Training in Gymnastics for Children Under 18 Years of Age
# 844 Training in the Arts of Combat and Self-Defense for Both Adults and Children (40% or More Children)
# 845 Training in the Arts of Combat and Self-Defense for Both Adults and Children (Less Than 40% Children)
# 846 Training in the Arts of Combat and Self-Defense for Children Under 18 Years of Age
# 847 Training in The Arts of Combat and Self-Defense, Music, Art, Gymnastics, Dance for Children Under 18 Years of Age (40% Or More Children)
# 848 Training in The Arts of Combat and Self-Defense, Music, Art, Gymnastics, Dance for Children Under 18 Years of Age (Less Than 40% Children)
# 849 Travel Agency - No Ticket Printing (Home Based Business)
# 850 Travel Services
# 851 Upholstery Cleaning/Repair - Offsite
# 852 Upholstery Cleaning/Repair - Onsite
# 853 Use of Explosives
# 855 Valet Parking Operator
# 856 Vending Machines (Sodas, Candy, Chips)
# 857 Operate a Veterinary Hospital
# 859 Virtual Office Services
# 863 Event Planning Services / Wedding Planner (Home Based Business)
# 864 Wholesale Food Sales
# 865 Wholesale Tobacco Product Sales
# 866 Window Tinting, Body Work, Painting
# 867 Window Washer, Vehicle Washer (Home Based Business)
# 868 Wrigley Field
# 890 Children's Activities Facilities
# 892 Indoor Special Event
# 894 Hair Services
# 895 Nail Services
# 896 Skincare Services
# 897 Financial Services
# 898 Computer Design/Development Consulting
# 899 Rental of Furniture
# 900 Sale of Furniture
# 901 Heating, Ventilation and Air Conditioning Services - Residential
# 902 Heating, Ventilation and Air Conditioning Services - Commercial
# 903 Self Storage Facility
# 904 Retail Sales of General Merchandise
# 905 After School Program / Tutoring Children Under 18 Years of Age
# 910 Sale of Art
# 911 Retail Sales of Clothing / Accessories / Shoes
# 912 Debt Collecting - Administrative Commercial Office
# 914 Roof Repair and Installation
# 915 Street Performer, Moving Along the Public Way (Special)
# 916 Music and Dance
# 921 Retail Sales of Flowers
# 922 Retail Sales of Cell Phones and Accessories
# 923 Retail Sales of Jewelry and Jewelry Repair
# 924 Wholesale Jewelry, Watches and Accessories
# 925 Miscellaneous Wholesale
# 926 Fitness Classes
# 927 Yoga Instruction
# 928 Training in The Arts of Combat and Self-Defense, Music, Art, Gymnastics, Dance for Adults
# 929 Miscellaneous Manufacturing
# 930 Operation of a Hand Car Wash
# 931 Retail and Wholesale of Perishable Foods
# 932 Retail Sales of Packaged Liquor on Sundays from 8AM - 11AM
# 936 Retail Sales of Tobacco Accessories
# 937 Retail Sales of Tobacco and Flavored Tobacco Products
# 940 Transportation Network Provider
# 941 Moving Company
# 942 5 Day Single - Special Event Food
# 943 5 Day Single - Special Event Food, Mobile Food Vehicle
# 944 10 Day Multiple - Special Event Food
# 946 180 Day Multiple - Special Event Food
# 947 180 Day Multiple - Special Event Food, Mobile Food Vehicle
# 948 1 Yr Multiple - Special Event Food
# 949 1 Yr Multiple - Special Event Food, Mobile Food Vehicle
# 950 Provide Animal Day Care Services
# 951 Instruction in Dance for Children Under 18 Years of Age
# 952 Instruction in Dance for Both Children and Adults (40% or More Children)
# 953 Instruction in Dance for Both Children and Adults (Less Than 40% Children)
# 954 Retail Sales of Animal Treats and Animal Food
# 955 Provide Dog Walking Services
# 956 Provide Waxing Services
# 958 Retail Sales of Appliances
# 960 Art Design
# 961 Retail Sales of Live Poultry
# 962 Provide Parking Spaces For a Fee - Available and Advertised to the Public - Entertainment Garage
# 963 Automatic Food Vending Machine Business
# 964 Excavation Services
# 966 Sales of Packaged Food From a Non-Motorized Cart (Mobile Prepared Food Vendor)
# 967 Sampling of Vaping Products on Premises
# 968 Combination - Street Performer and Retail Sales of General Merchandise, Whole Uncut Fruits/Vegetables, Flowers
# 969 Combination (Special)- Street Performer and Retail Sales of General Merchandise, Whole Uncut Fruits/Vegetables, Flowers
# 970 Wholesale of Liquid Nicotine and Products
# 971 Industrial Private Event Venue
# 972 Non Traditional Business Activity
# 977 Retail Sale of Funeral Related Items
# 978 Animal Shelter Cafe Permit
# 979 Mobile Boutique Operator
# 980 Wrigley Field Sports Plaza
# 981 Shared Housing Operator - Host of More Than One Shared Housing Unit
# 989 Buying and Reselling of Used Cell Phones
# 993 Consumption of Liquor on Premises - Riverwalk Venue
# 994 Consumption of Liquor on Premises - Lakefront Venue
# 996 Special Event Beer, Wine & Spirits
# 997 Private Booting Registration
# 998 Provide Foot Massage - Fully Clothed/No Disrobing
# 999 Provide Non-Invasive Cupping Therapy

# %% [markdown]
# Are any of these categories of Business Activities interesting for this project? Are there activities which might correspond to increased / decreased crime?
#
# Possible items of interest (to be narrowed down):
#
# 638 Consumption of Liquor on Premises
#
# 639 Consumption of Liquor on Premises, Not for Profit
#
# 640 Deli, Butcher or Bakery
#
# 664 Fortune Telling, Astrology, Tarot Card Reading Only
#
# 666 Operation of a Fuel Filling Station
#
# 676 Hotel - 7 or More Sleeping Rooms
#
# 688 Jewelry, Watches and Accessories
#
# 689 Junk Peddler
#
# 692 Laundromat - Self Service
#
# 704 Massage Establishment
#
# 725 Provide Parking Spaces For a Fee - Available and Advertised to the Public
#
# 726 Provide Parking Spaces For a Fee - to Residents, Tenants, Users, Employees and/or Guests (Not Available or Advertised to the Public)
#
# 728 Operate a Pet Shop / Sales of Animals
#
# 732 Pledging of Property for Money (Pawn)
#
# 735 Preparation of Food and Dining on Premise With Seating
#
# 745 Provide Full Body Massage Services
#
# 763 Retail Sale of Tobacco
#
# 774 Retail Sales of Packaged Liquor
#
# 776 Retail Sales of Tobacco Products
#
# 781 Sale of Food Prepared Onsite With Dining Area
#
# 784 Sale of Liquor Outdoors on Private Property
#
# 785 Sale of Liquor Until 4am, Monday - Saturday and 5am on Sunday
#
# 810 Smoking of Tobacco on Premises
#
# 811 Smoking of Tobacco With a Mouthpiece Attached to a Container of Water Through Which Smoke is Drawn and Cooled
#
# 828 Tattoo / Permanent Body Art and Make-Up / Micro Blading
#
# 829 Tavern - Consumption of Liquor on Premise
#
# 903 Self Storage Facility
#
# 932 Retail Sales of Packaged Liquor on Sundays from 8AM - 11AM
#
# 936 Retail Sales of Tobacco Accessories
#
# 937 Retail Sales of Tobacco and Flavored Tobacco Products
#
# 961 Retail Sales of Live Poultry
#
# 967 Sampling of Vaping Products on Premises
#
# 993 Consumption of Liquor on Premises - Riverwalk Venue
#
# 994 Consumption of Liquor on Premises - Lakefront Venue

# %% [markdown]
# # Data Wrangling - Chicago Crime

# %% [markdown]
# ## Import the file and inspect its basic characteristics

# %%
df = pd.read_csv('crimes_2019.csv', index_col='ID')

# %%
df.head()
# Out:
#          Case Number             Date                                Block  \
# ID
# 11734802    JC301648   6/11/2019 6:00                  033XX W FILLMORE ST
# 12080437    JD265831   11/1/2019 5:00               063XX S CALIFORNIA AVE
# 11721309    JC288956   6/2/2019 12:22              044XX W WASHINGTON BLVD
# 12078686    JD264973   6/15/2019 0:01                    014XX W GEORGE ST
# 11725655    JC286220  5/31/2019 12:05  079XX S DR MARTIN LUTHER KING JR DR
#
#           IUCR Primary Type                              Description  \
# ID
# 11734802  1812    NARCOTICS    POSSESS - CANNABIS MORE THAN 30 GRAMS
# 12080437   486      BATTERY                  DOMESTIC BATTERY SIMPLE
# 11721309  2017    NARCOTICS            MANUFACTURE / DELIVER - CRACK
# 12078686   530      ASSAULT      AGGRAVATED - OTHER DANGEROUS WEAPON
# 11725655  2014    NARCOTICS  MANUFACTURE / DELIVER -  HEROIN (WHITE)
#
#                            Location Description  Arrest  Domestic  Beat  ...  \
# ID                                                                       ...
# 11734802  POLICE FACILITY / VEHICLE PARKING LOT   False     False  1134  ...
# 12080437                              RESIDENCE   False      True   825  ...
# 11721309                 VEHICLE NON-COMMERCIAL   False     False  1113  ...
# 12078686                                  ALLEY   False     False  1932  ...
# 11725655                               SIDEWALK   False     False   623  ...
#
#           Ward  Community Area  FBI Code X Coordinate  Y Coordinate  Year  \
# ID
# 11734802  24.0              29        18          NaN           NaN  2019
# 12080437  17.0              66       08B          NaN           NaN  2019
# 11721309  28.0              26        18          NaN           NaN  2019
# 12078686  32.0               6       04A    1166295.0     1919354.0  2019
# 11725655   6.0              44        18          NaN           NaN  2019
#
#                Updated On   Latitude  Longitude                     Location
# ID
# 11734802  6/18/2020 15:48        NaN        NaN                          NaN
# 12080437  6/18/2020 15:48        NaN        NaN                          NaN
# 11721309  6/18/2020 15:48        NaN        NaN                          NaN
# 12078686  6/18/2020 15:46  41.934286 -87.664279  (41.93428599, -87.66427875)
# 11725655  6/18/2020 15:48        NaN        NaN                          NaN
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 259210 entries, 11734802 to 24554
# Data columns (total 21 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Case Number           259210 non-null  object
#  1   Date                  259210 non-null  object
#  2   Block                 259210 non-null  object
#  3   IUCR                  259210 non-null  object
#  4   Primary Type          259210 non-null  object
#  5   Description           259210 non-null  object
#  6   Location Description  258144 non-null  object
#  7   Arrest                259210 non-null  bool
#  8   Domestic              259210 non-null  bool
#  9   Beat                  259210 non-null  int64
#  10  District              259210 non-null  int64
#  11  Ward                  259195 non-null  float64
#  12  Community Area        259210 non-null  int64
#  13  FBI Code              259210 non-null  object
#  14  X Coordinate          258033 non-null  float64
#  15  Y Coordinate          258033 non-null  float64
#  16  Year                  259210 non-null  int64
#  17  Updated On            259210 non-null  object
#  18  Latitude              258033 non-null  float64
#  19  Longitude             258033 non-null  float64
#  20  Location              258033 non-null  object
# dtypes: bool(2), float64(5), int64(4), object(10)
# memory usage: 40.0+ MB

# %% [markdown]
# ## Check the columns for null values

# %%
df.isnull().sum()
# Out:
# Case Number                0
# Date                       0
# Block                      0
# IUCR                       0
# Primary Type               0
# Description                0
# Location Description    1066
# Arrest                     0
# Domestic                   0
# Beat                       0
# District                   0
# Ward                      15
# Community Area             0
# FBI Code                   0
# X Coordinate            1177
# Y Coordinate            1177
# Year                       0
# Updated On                 0
# Latitude                1177
# Longitude               1177
# Location                1177
# dtype: int64

# %% [markdown]
# Nulls for the location-based columns is our biggest problem since the purpose of this project is to study crime based on other factors at the same location. This will be addressed below.

# %% [markdown]
# ## Explore the contents of the data, column by column

# %%
df['Block'].value_counts()
# Out:
# 001XX N STATE ST         1087
# 008XX N MICHIGAN AVE      472
# 0000X W TERMINAL ST       427
# 0000X S STATE ST          411
# 0000X N STATE ST          363
#                          ...
# 0000X E 45TH ST             1
# 062XX N Kirkwood Ave        1
# 081XX S CHAMPLAIN AVE       1
# 016XX W FARRAGUT AVE        1
# 057XX N MERRIMAC AVE        1
# Name: Block, Length: 27777, dtype: int64

# %%
df['IUCR'].value_counts().sort_index()
# Out:
# 031A    2640
# 031B      45
# 033A     239
# 033B       6
# 041A    1606
#         ...
# 928        1
# 930      593
# 935       26
# 937        1
# 938        1
# Name: IUCR, Length: 318, dtype: int64

# %%
df['IUCR'].value_counts()
# Out:
# 486     23586
# 820     23131
# 460     16442
# 810     14646
# 560     13880
#         ...
# 5122        1
# 1682        1
# 142B        1
# 928         1
# 4240        1
# Name: IUCR, Length: 318, dtype: int64

# %%
df['Primary Type'].value_counts()
# Out:
# THEFT                                62387
# BATTERY                              49487
# CRIMINAL DAMAGE                      26671
# ASSAULT                              20608
# DECEPTIVE PRACTICE                   18330
# OTHER OFFENSE                        16696
# NARCOTICS                            14238
# BURGLARY                              9627
# MOTOR VEHICLE THEFT                   8978
# ROBBERY                               7989
# CRIMINAL TRESPASS                     6817
# WEAPONS VIOLATION                     6325
# OFFENSE INVOLVING CHILDREN            2293
# INTERFERENCE WITH PUBLIC OFFICER      1546
# PUBLIC PEACE VIOLATION                1520
# SEX OFFENSE                           1297
# CRIM SEXUAL ASSAULT                   1244
# PROSTITUTION                           680
# HOMICIDE                               503
# ARSON                                  378
# CRIMINAL SEXUAL ASSAULT                356
# LIQUOR LAW VIOLATION                   231
# STALKING                               223
# CONCEALED CARRY LICENSE VIOLATION      217
# KIDNAPPING                             172
# INTIMIDATION                           163
# GAMBLING                               142
# OBSCENITY                               58
# HUMAN TRAFFICKING                       11
# PUBLIC INDECENCY                        11
# OTHER NARCOTIC VIOLATION                 8
# NON-CRIMINAL                             4
# Name: Primary Type, dtype: int64

# %%
df['Location Description'].value_counts()
# Out:
# STREET                      56450
# RESIDENCE                   42878
# APARTMENT                   34638
# SIDEWALK                    20181
# OTHER                       10563
#                             ...
# CHA PLAY LOT                    1
# TRAILER                         1
# HORSE STABLE                    1
# SCHOOL - PRIVATE GROUNDS        1
# SPORTS ARENA / STADIUM          1
# Name: Location Description, Length: 155, dtype: int64

# %%
df['Arrest'].value_counts().sort_index()
# Out:
# False    204169
# True      55041
# Name: Arrest, dtype: int64

# %%
df['Domestic'].value_counts().sort_index()
# Out:
# False    216140
# True      43070
# Name: Domestic, dtype: int64

# %%
df['Beat'].value_counts().sort_index()
# Out:
# 111     2496
# 112     2165
# 113     1049
# 114     1190
# 121      786
#         ...
# 2531     686
# 2532    1018
# 2533    1597
# 2534    1193
# 2535     837
# Name: Beat, Length: 274, dtype: int64

# %%
df['District'].value_counts().sort_index()
# Out:
# 1     15198
# 2     11182
# 3     12433
# 4     13975
# 5     11307
# 6     16778
# 7     13600
# 8     15596
# 9     10915
# 10    12431
# 11    18301
# 12    13123
# 14     9239
# 15     9951
# 16     8199
# 17     6719
# 18    15124
# 19    11770
# 20     4345
# 22     8207
# 24     7956
# 25    12854
# 31        7
# Name: District, dtype: int64

# %%
df['Ward'].value_counts().sort_index()
# Out:
# 1.0      4799
# 2.0      5254
# 3.0      7348
# 4.0      6923
# 5.0      5892
# 6.0      9700
# 7.0      7506
# 8.0      8119
# 9.0      7849
# 10.0     3721
# 11.0     3086
# 12.0     3206
# 13.0     2245
# 14.0     2929
# 15.0     3786
# 16.0     7877
# 17.0     8362
# 18.0     3773
# 19.0     2005
# 20.0     8005
# 21.0     8276
# 22.0     3320
# 23.0     2450
# 24.0    11024
# 25.0     4801
# 26.0     3810
# 27.0    12390
# 28.0    12860
# 29.0     5912
# 30.0     2665
# 31.0     2892
# 32.0     3257
# 33.0     2376
# 34.0     6666
# 35.0     2813
# 36.0     2816
# 37.0     7753
# 38.0     1818
# 39.0     2204
# 40.0     2729
# 41.0     2828
# 42.0    16604
# 43.0     3065
# 44.0     4217
# 45.0     2493
# 46.0     3233
# 47.0     2353
# 48.0     2581
# 49.0     3997
# 50.0     2607
# Name: Ward, dtype: int64

# %%
df['Community Area'].value_counts().sort_index()
# Out:
# 1     4037
# 2     3441
# 3     3339
# 4     1793
# 5     1270
#       ...
# 73    3207
# 74     466
# 75    1868
# 76    1623
# 77    2493
# Name: Community Area, Length: 77, dtype: int64

# %%
df['FBI Code'].value_counts().sort_index()
# Out:
# 01A      495
# 01B        8
# 04A     5840
# 04B     7860
# 08A    18358
# 08B    42363
# 10      1560
# 11     16661
# 12        31
# 13        43
# 14     26671
# 15      6545
# 16       680
# 17      1864
# 18     14243
# 19       143
# 2       1768
# 20       804
# 22       231
# 24      3033
# 26     20650
# 3       7989
# 5       9627
# 6      62387
# 7       8978
# 9        378
# Name: FBI Code, dtype: int64

# %% [markdown]
# ## Address the null values

# %% [markdown]
# For the rows that have null location data, create a dictionary of replacement values
#
# Are there other rows in our data that have the same "Block" value and have valid location data? Take the mean of those values for our dictionary.

# %%
# Create a DataFrame of just rows with null location data
df_nulls = df[df.Latitude.isnull()]
print("Before removing duplicates,", df_nulls.shape[0], "rows have NULL location data.")

# Remove duplicate rows in df_nulls
df_nulls = df_nulls.drop_duplicates(subset='Block', keep="first")
print("After removing duplicates,", df_nulls.shape[0], "rows have NULL location data.")
# Out:
# Before removing duplicates, 1177 rows have NULL location data.
# After removing duplicates, 982 rows have NULL location data.

# %%
# Create latitude and longitude dictionaries for rows with missing location data. The key is the Block column
# Every row with a null location has a value for Block. Take the mean of the other rows with the same Block. 
#
# THIS TAKES SEVERAL SECONDS TO RUN

block_lat = {}
block_long = {}
for block in df_nulls.Block:
    block_lat[block] = df[df.Block == block].Latitude.mean()
    block_long[block] = df[df.Block == block].Longitude.mean()

# %%
# Now that we have the dictionaries, update the original dataframe

# Gather the indexes of the rows that have NULL location data
null_loc_indexes = df[df.Latitude.isnull()].index

# Update the location data with the dictionary values
#
# THIS TAKES A FEW SECONDS TO RUN

for i in null_loc_indexes:
    df.loc[df.index == i, 'Latitude'] = block_lat[df.loc[i].Block]
    df.loc[df.index == i, 'Longitude'] = block_long[df.loc[i].Block]
    df.loc[df.index == i, 'Location'] = str(tuple([block_lat[df.loc[i].Block], block_long[df.loc[i].Block]]))

# %%
# How many rows still have NULL location data?
print("Still have", df[df.Latitude.isnull()].shape[0], "rows with NULL location data.")
# Out:
# Still have 193 rows with NULL location data.

# %% [markdown]
# Given that less than 0.1% of rows have missing location data, we will delete these rows.

# %%
# Print the number of rows in the original dataframe
print("Number of rows in original dataframe =", df.shape[0])
print("Still have", df[df.Latitude.isnull()].shape[0], "rows with NULL location data.")

# Create a new dataframe without the rows with NULL location data
null_locations = df[df.Latitude.isnull()].index
crimes = df.drop(null_locations)

# Print the number of rows in the new dataframe
print("Number of rows in cleaned dataframe =", crimes.shape[0])
# Out:
# Number of rows in original dataframe = 259210
# Still have 193 rows with NULL location data.
# Number of rows in cleaned dataframe = 259017

# %% [markdown]
# We see the number of rows drops equals the number of rows that had NULL location data.

# %% [markdown]
# ## Location outside Chicago

# %%
# Find all crimes with location data outside Chicago
outside_chicago = crimes.Latitude < 41.644
print(crimes[outside_chicago][['Date', 'Primary Type', 'Location']])

# Print the counts of total rows and rows to be dropped
print('Rows before dropping:', crimes.shape[0])
print('Crimes outside Chicago:',
      crimes[outside_chicago].shape[0])

# Using the inverted boolean, keep just the rows that don't meet the condition
crimes = crimes[~outside_chicago]
print('Rows after dropping:', crimes.shape[0])
# Out:
#                       Date                Primary Type  \
# ID
# 11932439   12/26/2019 0:18                       THEFT
# 11923158   12/16/2019 7:30                     BATTERY
# 11889657  11/12/2019 18:22                   NARCOTICS
# 11882333   11/4/2019 21:49                     BATTERY
# 11852262   10/6/2019 10:00  OFFENSE INVOLVING CHILDREN
# 11852129   10/6/2019 10:40                     BATTERY
# 11851392   10/5/2019 11:30                       THEFT
# 11850761   10/4/2019 22:08           CRIMINAL TRESPASS
# 11828439   9/14/2019 16:00                     ASSAULT
# 11818115     9/5/2019 1:54          DECEPTIVE PRACTICE
# 11790294    8/11/2019 5:00                     BATTERY
# 11787315    8/8/2019 15:00           CRIMINAL TRESPASS
# 11784405    8/5/2019 15:00             CRIMINAL DAMAGE
# 11763800   7/19/2019 19:52                     BATTERY
# 11760499    7/17/2019 0:02                       THEFT
# 11760843    7/3/2019 10:00             CRIMINAL DAMAGE
# 11743412     7/2/2019 8:00                     BATTERY
# 11732417    6/23/2019 9:03                     BATTERY
# 11732007   6/22/2019 21:45                       THEFT
# 11731525    6/22/2019 9:30                     BATTERY
# 11667191    4/26/2019 3:15                     ROBBERY
# 11670961   4/29/2019 22:07         MOTOR VEHICLE THEFT
# 11674448     5/3/2019 2:39         MOTOR VEHICLE THEFT
#
#                                Location
# ID
# 11932439     (36.6194464, -91.68656568)
# 11923158     (36.6194464, -91.68656568)
# 11889657  (36.619446395, -91.686565684)
# 11882333     (36.6194464, -91.68656568)
# 11852262     (36.6194464, -91.68656568)
# 11852129     (36.6194464, -91.68656568)
# 11851392     (36.6194464, -91.68656568)
# 11850761     (36.6194464, -91.68656568)
# 11828439     (36.6194464, -91.68656568)
# 11818115     (36.6194464, -91.68656568)
# 11790294     (36.6194464, -91.68656568)
# 11787315     (36.6194464, -91.68656568)
# 11784405     (36.6194464, -91.68656568)
# 11763800     (36.6194464, -91.68656568)
# 11760499     (36.6194464, -91.68656568)
# 11760843     (36.6194464, -91.68656568)
# 11743412     (36.6194464, -91.68656568)
# 11732417  (36.619446395, -91.686565684)
# 11732007     (36.6194464, -91.68656568)
# 11731525     (36.6194464, -91.68656568)
# 11667191     (36.6194464, -91.68656568)
# 11670961     (36.6194464, -91.68656568)
# 11674448     (36.6194464, -91.68656568)
# Rows before dropping: 259017
# Crimes outside Chicago: 23
# Rows after dropping: 258994

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Counts

# %%
bl_trimmed['LICENSE DESCRIPTION'].value_counts()
# Out:
# Limited Business License                               14969
# Retail Food Establishment                              10523
# Regulated Business License                              7115
# Consumption on Premises - Incidental Activity           2383
# Tobacco                                                 2204
# Motor Vehicle Services License                          1710
# Peddler License                                         1550
# Package Goods                                           1149
# Children's Services Facility License                     994
# Tavern                                                   888
# Manufacturing Establishments                             814
# Public Place of Amusement                                781
# Commercial Garage                                        645
# Outdoor Patio                                            594
# Wholesale Food Establishment                             462
# Filling Station                                          420
# Raffles                                                  407
# Valet Parking Operator                                   394
# Shared Kitchen User                                      375
# Animal Care License                                      359
# Secondhand Dealer                                        241
# Caterer's Liquor License                                 240
# Special Event Food                                       214
# Pop-Up Retail User                                       156
# Late Hour                                                135
# Special Event Liquor                                      78
# Shared Housing Unit Operator                              70
# Music and Dance                                           65
# Food - Shared Kitchen - Supplemental                      64
# Pawnbroker                                                62
# Not-For-Profit Club                                       59
# Mobile Food License                                       55
# Private Booting Registration                              52
# Commercial Passenger Vessel                               34
# Indoor Special Event                                      19
# License Manager                                           18
# Affiliation                                               17
# Food - Shared Kitchen                                     13
# Pop-Up Establishment Host - Tier II                       13
# Wrigley Field                                             11
# Emerging Business                                          8
# Explosives                                                 8
# Heliports                                                  8
# Bicycle Messenger Service                                  6
# Pop-Up Food Est. User - Tier II                            4
# Transportation Network Provider                            4
# Massage Establishment                                      3
# Taxicab Two-Way Dispatch Service License                   3
# Navy Pier Kiosk License                                    2
# Pop-Up Food Est. User - Tier III                           1
# Pop-Up Food Est. User - Tier I                             1
# Retail Food - Seasonal Lakefront Food Establishment        1
# Name: LICENSE DESCRIPTION, dtype: int64

# %%
crimes['Primary Type'].value_counts()
# Out:
# THEFT                                62270
# BATTERY                              49471
# CRIMINAL DAMAGE                      26664
# ASSAULT                              20601
# DECEPTIVE PRACTICE                   18278
# OTHER OFFENSE                        16696
# NARCOTICS                            14236
# BURGLARY                              9627
# MOTOR VEHICLE THEFT                   8975
# ROBBERY                               7988
# CRIMINAL TRESPASS                     6813
# WEAPONS VIOLATION                     6325
# OFFENSE INVOLVING CHILDREN            2292
# INTERFERENCE WITH PUBLIC OFFICER      1545
# PUBLIC PEACE VIOLATION                1518
# SEX OFFENSE                           1297
# CRIM SEXUAL ASSAULT                   1244
# PROSTITUTION                           680
# HOMICIDE                               502
# ARSON                                  378
# CRIMINAL SEXUAL ASSAULT                356
# LIQUOR LAW VIOLATION                   231
# STALKING                               223
# CONCEALED CARRY LICENSE VIOLATION      217
# KIDNAPPING                             172
# INTIMIDATION                           163
# GAMBLING                               142
# OBSCENITY                               58
# HUMAN TRAFFICKING                       11
# PUBLIC INDECENCY                        11
# OTHER NARCOTIC VIOLATION                 6
# NON-CRIMINAL                             4
# Name: Primary Type, dtype: int64

# %%
pawns = bl_trimmed[bl_trimmed['LICENSE DESCRIPTION'] == 'Pawnbroker']
taverns = bl_trimmed[bl_trimmed['LICENSE DESCRIPTION'] == 'Tavern']

arson = crimes[crimes['Primary Type'] == 'ARSON']
assault = crimes[crimes['Primary Type'] == 'ASSAULT']
battery = crimes[crimes['Primary Type'] == 'BATTERY']
burglary = crimes[crimes['Primary Type'] == 'BURGLARY']
criminal_damage = crimes[crimes['Primary Type'] == 'CRIMINAL DAMAGE']
homicide = crimes[crimes['Primary Type'] == 'HOMICIDE']
motor_vehicle_theft = crimes[crimes['Primary Type'] == 'MOTOR VEHICLE THEFT']
narcotics = crimes[crimes['Primary Type'] == 'NARCOTICS']
prostitution = crimes[crimes['Primary Type'] == 'PROSTITUTION']
robbery = crimes[crimes['Primary Type'] == 'ROBBERY']
theft = crimes[crimes['Primary Type'] == 'THEFT']

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Plots of Businesses by Type

# %%
neighborhoods = geopandas.GeoDataFrame.from_file('chicago map.shp')
neighborhoods.plot(figsize=(8, 8), alpha=0.2, edgecolor='k')
plt.scatter(pawns.LONGITUDE, pawns.LATITUDE, color='red', alpha=0.4)
plt.title("Pawnbrokers in Chicago")
plt.show()

# %%
neighborhoods.plot(figsize=(8, 8), alpha=0.2, edgecolor='k')
plt.scatter(taverns.LONGITUDE, taverns.LATITUDE, color='red', alpha=0.3, s=10)
plt.title("Taverns in Chicago")
plt.show()

# %% [markdown]
# ### Plots of Crimes by Type

# %%
neighborhoods.plot(figsize=(8, 8), alpha=0.2, edgecolor='k')
plt.scatter(arson.Longitude, arson.Latitude, color='b', alpha=0.3, s=10)
plt.title("Arson in Chicago")
plt.show()

# %%
neighborhoods.plot(figsize=(8, 8), alpha=0.2, edgecolor='k')
plt.scatter(assault.Longitude, assault.Latitude, color='b', alpha=0.05, s=10)
plt.title("Assault in Chicago")
plt.show()

# %%
# Note that the transparency of the data markers is set extremely low
neighborhoods.plot(figsize=(8, 8), alpha=0.2, edgecolor='k')
plt.scatter(battery.Longitude, battery.Latitude, color='b', alpha=0.01, s=10)
plt.title("Battery in Chicago")
plt.show()

# %%
neighborhoods.plot(figsize=(8, 8), alpha=0.2, edgecolor='k')
plt.scatter(burglary.Longitude, burglary.Latitude, color='b', alpha=0.1, s=10)
plt.title("Burglary in Chicago")
plt.show()

# %%
neighborhoods.plot(figsize=(8, 8), alpha=0.2, edgecolor='k')
plt.scatter(criminal_damage.Longitude, criminal_damage.Latitude, color='b', alpha=0.05, s=10)
plt.title("Criminal Damage in Chicago")
plt.show()

# %%
neighborhoods.plot(figsize=(8, 8), alpha=0.2, edgecolor='k')
plt.scatter(homicide.Longitude, homicide.Latitude, color='b', alpha=0.3, s=10)
plt.title("Homicide in Chicago")
plt.show()

# %%
neighborhoods.plot(figsize=(8, 8), alpha=0.2, edgecolor='k')
plt.scatter(motor_vehicle_theft.Longitude, motor_vehicle_theft.Latitude, color='b', alpha=0.1, s=10)
plt.title("Motor Vehicle Theft in Chicago")
plt.show()

# %%
neighborhoods.plot(figsize=(8, 8), alpha=0.2, edgecolor='k')
plt.scatter(narcotics.Longitude, narcotics.Latitude, color='b', alpha=0.1, s=10)
plt.title("Narcotics in Chicago")
plt.show()

# %%
neighborhoods.plot(figsize=(8, 8), alpha=0.2, edgecolor='k')
plt.scatter(prostitution.Longitude, prostitution.Latitude, color='b', alpha=0.1, s=10)
plt.title("Prostitution in Chicago")
plt.show()

# %% [markdown]
# Prostitution is clustered in a few locations.

# %%
neighborhoods.plot(figsize=(8, 8), alpha=0.2, edgecolor='k')
plt.scatter(robbery.Longitude, robbery.Latitude, color='b', alpha=0.1, s=10)
plt.title("Robbery in Chicago")
plt.show()

# %%
neighborhoods.plot(figsize=(8, 8), alpha=0.2, edgecolor='k')
plt.scatter(theft.Longitude, theft.Latitude, color='b', alpha=0.01, s=10)
plt.title("Theft in Chicago")
plt.show()

# %% [markdown]
# ### Violent Crime
#
# Violent crime is defined on the following City of Chicago website. It is classified in the crime dataset by the IUCR (Illinois Uniform Crime Reporting) code. In general terms, violent crime consists of homicide, criminal sexual assault, robbery, aggravated assault, and aggravated battery.
#
# <http://gis.chicagopolice.org/clearmap_crime_sums/crime_types.html#N01A>

# %%
# Create a list of codes for violent crimes
IUCR_vc = ['110', '130', '261', '262', '263', '264', '265', '266', '271', '272', '273', '274', 
           '275', '281', '291', '1753', '1754', '312', '313', '031A', '031B', '320', '325', '326', 
           '330', '331', '334', '337', '033A', '033B', '340', '051A', '051B', '520', '530', '550', 
           '551', '552', '553', '555', '556', '557', '558', '041A', '041B', '420', '430', '450', 
           '451', '452', '453', '461', '462', '479', '480', '481', '482', '483', '485', '488', 
           '489', '490', '491', '492', '493', '495', '496', '497', '498', '510']
violent_crimes = crimes[crimes['IUCR'].isin(IUCR_vc)]

neighborhoods.plot(figsize=(8, 8), alpha=0.2, edgecolor='k')
plt.scatter(violent_crimes.Longitude, violent_crimes.Latitude, color='b', alpha=0.04, s=10)
plt.title("Violent Crime in Chicago")
plt.show()

# %%
sns.set(style="white")
#neighborhoods.plot(figsize=(10, 10), alpha=0.2, edgecolor='k')
with sns.axes_style("white"):
    sns.jointplot(x=violent_crimes.Longitude, y=violent_crimes.Latitude, kind="hex", cmap="GnBu");

# %%
# Add crime column to the geopandas of Chicago neighborhoods

violent_crimes_by_ca = violent_crimes['Community Area'].value_counts()

for comm_area in neighborhoods['area_num_1']:
    neighborhoods.loc[neighborhoods.area_num_1 == comm_area,
                      'violent_crimes'] = violent_crimes_by_ca[int(comm_area)]

plt.style.use('seaborn-white')

fig, ax = plt.subplots(figsize=(8, 8))
divider = make_axes_locatable(ax)
plt.title("Violent Crimes by Community Area")
#plt.scatter(pawns.LONGITUDE, pawns.LATITUDE, color='red', alpha=1)

cax = divider.append_axes('right', size='2%', pad=0.6)
cax.set_xlabel('Violent Crimes')

neighborhoods.plot(column='violent_crimes', cmap='plasma', legend=True, ax=ax, cax=cax)
plt.show()

# %% [markdown]
# ### All crime

# %%
neighborhoods.plot(figsize=(8, 8), alpha=0.2, edgecolor='k')
plt.scatter(crimes.Longitude, crimes.Latitude, color='b', alpha=0.002, s=10)
plt.title("Crime in Chicago")
plt.show()

# %%
with sns.axes_style("white"):
    sns.jointplot(x=crimes.Longitude, y=crimes.Latitude, kind="hex", cmap="plasma");

# %%
# Add crime column to the geopandas of Chicago neighborhoods

crimes_by_ca = crimes['Community Area'].value_counts()

for comm_area in neighborhoods['area_num_1']:
    neighborhoods.loc[neighborhoods.area_num_1 == comm_area,
                      'all_crimes'] = crimes_by_ca[int(comm_area)]

plt.style.use('seaborn-white')

fig, ax = plt.subplots(figsize=(8, 8))
divider = make_axes_locatable(ax)
plt.title("All Crimes by Community Area")
#plt.scatter(pawns.LONGITUDE, pawns.LATITUDE, color='red', alpha=1)

cax = divider.append_axes('right', size='2%', pad=0.6)
cax.set_xlabel('All Crimes')

neighborhoods.plot(column='all_crimes', cmap='plasma', legend=True, ax=ax, cax=cax)
plt.show()

# %% [markdown]
# ## Crimes around Pawnbrokers

# %% [markdown]
# Does a pawnshop attract certain types of crime? One could imagine a criminal burglarizing a home or vehicle and selling the stolen goods at a pawnshop. In neighborhoods with pawnshops, do we see clusters of burglaries?

# %%
neighborhoods.plot(figsize=(10, 10), alpha=0.2, edgecolor='k')
plt.scatter(burglary.Longitude, burglary.Latitude, color='b', alpha=0.1, s=10)

plt.scatter(pawns.LONGITUDE, pawns.LATITUDE, color='red', alpha=0.4)

plt.title("Burglary and Pawnbrokers in Chicago")
plt.show()

# %% [markdown]
# It is hard to see a correlation. There are pawnbrokers in areas with low and high burglaries, and there are areas of high burglaries that have no pawnbrokers. Moreover, areas with multiple pawnbrokers do not coincide with the most burglaries.
#
# What about robberies? One could imagine a criminal mugging a person then selling their watch, jewelry, etc. at a pawnshop.

# %%
neighborhoods.plot(figsize=(10, 10), alpha=0.2, edgecolor='k')
plt.scatter(robbery.Longitude, robbery.Latitude, color='b', alpha=0.1, s=10)
plt.scatter(pawns.LONGITUDE, pawns.LATITUDE, color='red', alpha=0.4)

plt.title("Robbery and Pawnbrokers in Chicago")
plt.show()

# %% [markdown]
# There might be a correlation between robbery and pawnbrokers, at least in some neighborhoods. However, there are large concentrations of robbery in the west and south sides without a similarly high number of pawnbrokers. There must be other factors contributing to the incidence of robberies.

# %% [markdown]
# ## Crimes around Taverns
#
# Does a tavern attract certain types of crime? Hollywood movies are replete with bar fights and stories of two guys who "take it outside" to fight. In the area around a tavern, do we see clusters of assault and battery?

# %%
neighborhoods.plot(figsize=(10, 10), alpha=0.2, edgecolor='k')
plt.scatter(assault.Longitude, assault.Latitude, color='b', alpha=0.05, s=10)
plt.scatter(taverns.LONGITUDE, taverns.LATITUDE, color='red', alpha=0.3, s=10)

plt.title("Taverns and Assault in Chicago")
plt.show()

# %% [markdown]
# The high density of taverns in the north part of the city does not correspond to an equally dense pattern of assault. The large dark blue areas on the west and south sides do not correspond to a similar density of taverns.

# %%
neighborhoods.plot(figsize=(10, 10), alpha=0.2, edgecolor='k')
plt.scatter(battery.Longitude, battery.Latitude, color='b', alpha=0.01, s=10)
plt.scatter(taverns.LONGITUDE, taverns.LATITUDE, color='red', alpha=0.3, s=10)

plt.title("Taverns and Battery in Chicago")
plt.show()

# %% [markdown]
# The plot does not appear to support a link between taverns and battery. The north side of Chicago has several taverns in areas with low concentrations of battery. The west side has a large dark blue area (high concentration of battery) with very few taverns.

# %% [markdown]
# # Socioeconomic data
#
# The Chicago Data Portal has socioeconomic indicators for each community area, last updated September 12, 2014.
#
# Source: https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2/data

# %% [markdown]
# ## Import and inspect data

# %%
socio = pd.read_csv("Census_Data_-_Selected_socioeconomic_indicators_in_Chicago__2008___2012.csv")
socio.rename(columns = {'Community Area Number':'area'}, inplace = True)

# %%
socio.head()
# Out:
#    area COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0   1.0         Rogers Park                         7.7
# 1   2.0          West Ridge                         7.8
# 2   3.0              Uptown                         3.8
# 3   4.0      Lincoln Square                         3.4
# 4   5.0        North Center                         0.3
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          18.2
# 1                                          20.8
# 2                                          11.8
# 3                                          13.4
# 4                                           4.5
#
#    PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 0                              27.5               23939            39.0
# 1                              38.5               23040            46.0
# 2                              22.2               35787            20.0
# 3                              25.5               37524            17.0
# 4                              26.2               57123             6.0

# %%
socio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 9 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   area                                          77 non-null     float64
#  1   COMMUNITY AREA NAME                           78 non-null     object
#  2   PERCENT OF HOUSING CROWDED                    78 non-null     float64
#  3   PERCENT HOUSEHOLDS BELOW POVERTY              78 non-null     float64
#  4   PERCENT AGED 16+ UNEMPLOYED                   78 non-null     float64
#  5   PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  78 non-null     float64
#  6   PERCENT AGED UNDER 18 OR OVER 64              78 non-null     float64
#  7   PER CAPITA INCOME                             78 non-null     int64
#  8   HARDSHIP INDEX                                77 non-null     float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 5.6+ KB

# %%
# Add a socioeconomic column to the geopandas of Chicago neighborhoods
# Note the trailing space in 'PER CAPITA INCOME '

neighborhoods = geopandas.GeoDataFrame.from_file('chicago map.shp')

# print(neighborhoods['area_num_1'])
for comm_area in neighborhoods['area_num_1']:
    neighborhoods.loc[neighborhoods.area_num_1 == comm_area,
                      'per_capita_income'] = float(socio.loc[socio.area == float(comm_area), 
                                                             'PER CAPITA INCOME '])
#    print(comm_area, socio.loc[socio.area == float(comm_area), 'PER CAPITA INCOME '],
#          neighborhoods.loc[neighborhoods.area_num_1 == comm_area, 'socio'])

plt.style.use('seaborn-white')

fig, ax = plt.subplots(figsize=(8, 8))
divider = make_axes_locatable(ax)
plt.title("Per Capita Income by Community Area")
#plt.scatter(pawns.LONGITUDE, pawns.LATITUDE, color='red', alpha=1)

cax = divider.append_axes('right', size='2%', pad=0.6)
cax.set_xlabel('Per Capita Income')

neighborhoods.plot(column='per_capita_income',
                   cmap='YlGnBu', legend=True, ax=ax, cax=cax)
plt.show()

# %% [markdown]
# ## Compare to crime

# %%
for comm_area in socio.area:
    if not math.isnan(comm_area):
        socio.loc[socio.area == comm_area, 'violent_crime'] = violent_crimes_by_ca[int(comm_area)]
        socio.loc[socio.area == comm_area, 'all_crime'] = crimes_by_ca[int(comm_area)]

# %%
socio.head()
# Out:
#    area COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0   1.0         Rogers Park                         7.7
# 1   2.0          West Ridge                         7.8
# 2   3.0              Uptown                         3.8
# 3   4.0      Lincoln Square                         3.4
# 4   5.0        North Center                         0.3
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          18.2
# 1                                          20.8
# 2                                          11.8
# 3                                          13.4
# 4                                           4.5
#
#    PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX  \
# 0                              27.5               23939            39.0
# 1                              38.5               23040            46.0
# 2                              22.2               35787            20.0
# 3                              25.5               37524            17.0
# 4                              26.2               57123             6.0
#
#    violent_crime  all_crime
# 0          285.0     4032.0
# 1          235.0     3439.0
# 2          262.0     3330.0
# 3          116.0     1791.0
# 4           53.0     1264.0

# %%
socio.plot.scatter(x='PERCENT OF HOUSING CROWDED', y='violent_crime', c='blue',
                   title="Violent Crime by Percent of Housing Crowded")

socio.plot.scatter(x='PERCENT HOUSEHOLDS BELOW POVERTY', y='violent_crime', c='blue',
                   title="Violent Crime by Percent of Households below Poverty")

socio.plot.scatter(x='PERCENT AGED 16+ UNEMPLOYED', y='violent_crime', c='blue',
                   title="Violent Crime by Percent Unemployed")

socio.plot.scatter(x='PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA', y='violent_crime', c='blue',
                   title="Violent Crime by Percent of Aged 25+ without HS Diploma")

socio.plot.scatter(x='PERCENT AGED UNDER 18 OR OVER 64', y='violent_crime', c='blue',
                   title="Violent Crime by Percent of Residents 18-64 years old")

socio.plot.scatter(x='PER CAPITA INCOME ', y='violent_crime', c='blue',
                   title="Violent Crime by Per Capita Income")

socio.plot.scatter(x='HARDSHIP INDEX', y='violent_crime', c='blue',
                   title="Violent Crime by Hardship Index")

# plot.show();

# %%
socio.plot.scatter(x='PERCENT OF HOUSING CROWDED', y='all_crime', c='red',
                   title="Crime by Percent of Housing Crowded")

socio.plot.scatter(x='PERCENT HOUSEHOLDS BELOW POVERTY', y='all_crime', c='red',
                   title="Crime by Percent of Households below Poverty")

socio.plot.scatter(x='PERCENT AGED 16+ UNEMPLOYED', y='all_crime', c='red',
                   title="Crime by Percent Unemployed")

socio.plot.scatter(x='PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA', y='all_crime', c='red',
                   title="Crime by Percent of Aged 25+ without HS Diploma")

socio.plot.scatter(x='PERCENT AGED UNDER 18 OR OVER 64', y='all_crime', c='red',
                   title="Crime by Percent of Residents 18-64 years old")

socio.plot.scatter(x='PER CAPITA INCOME ', y='all_crime', c='red',
                   title="Crime by Per Capita Income")

socio.plot.scatter(x='HARDSHIP INDEX', y='all_crime', c='red',
                   title="Crime by Hardship Index")

# plot.show();

# %% [markdown]
# # Appendix: Extra code that might be useful later

# %%
ddf = pd.DataFrame(np.random.random((200,3)))
ddf['date'] = pd.date_range('2000-1-1', periods=200, freq='D')
mask = (ddf['date'] > '2000-6-1') & (ddf['date'] <= '2000-6-10')
print(ddf.loc[mask])
# Out:
#             0         1         2       date
# 153  0.628425  0.409080  0.385390 2000-06-02
# 154  0.065660  0.561795  0.060495 2000-06-03
# 155  0.324587  0.127766  0.728083 2000-06-04
# 156  0.295986  0.122841  0.972502 2000-06-05
# 157  0.185299  0.784522  0.479509 2000-06-06
# 158  0.965422  0.011893  0.499177 2000-06-07
# 159  0.794201  0.143753  0.992597 2000-06-08
# 160  0.699104  0.874446  0.509626 2000-06-09
# 161  0.021242  0.161825  0.789991 2000-06-10

# %%
# Extra code that might be useful later
#
#sns.countplot(df["Location Description"])
#sns.countplot(df["Primary Type"])

#print(df.dtypes)
#print(df.loc[df.index == 11734802, 'Latitude'])
#df.loc[null_loc_indexes]

# Create a loop through the Latitude dictionary to see how many of the NaN rows now have valid data

# %%
#sns.set(style="darkgrid")

# Set up the figure
#f, ax = plt.subplots(figsize=(10, 10))
#ax.set_aspect("equal")

# Draw the density plot
#ax = sns.kdeplot(crimes.Longitude, crimes.Latitude, cmap="Reds", shade=True, shade_lowest=False)
